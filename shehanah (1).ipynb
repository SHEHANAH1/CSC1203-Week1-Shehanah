# %%
# Quistion 1

# %%
print('Welcome to python') #print Welcome....
# Out:
# Welcome to python

# %%
name = 'Shehanah' # store my name

# %%
print(name) # print my name
# Out:
# Shehanah

# %%
CourceName = 'Programming'  # store CourceName

# %%
print(CourceName)  # print CourceName
# Out:
# Programming

# %%
"""
ajjj
"""
# Out:
# '\najjj\n'

# %%
# Quistion 2

# %%
string_name = 'Alice'
print(type(string_name))
# Out:
# <class 'str'>

# %%
age = 20
print(type(age))
# Out:
# <class 'int'>

# %%
gpa = 3.75
print(type(gpa))
# Out:
# <class 'float'>

# %%
subjects = ["Math","python","physics"]
print(type(subjects))
# Out:
# <class 'list'>

# %%
string_info = {"id":101,"year":2}
print(type(string_info))
# Out:
# <class 'dict'>

# %%
skills = {"python","SQL"}
print(type(skills))
# Out:
# <class 'set'>

# %%
is_enrolled = True
print(type(is_enrolled))
# Out:
# <class 'bool'>

# %%
qrad_date = None
print(type(qrad_date))
# Out:
# <class 'NoneType'>
